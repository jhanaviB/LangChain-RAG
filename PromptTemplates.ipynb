# %% [markdown]
# Prompt Templates and Prompt Values

# %%
from langchain_core.prompts import PromptTemplate

# %%
TEMPLATE = '''
System:
{description}

Human:
I've recently adopted a {pet}.
Could you suggest some {pet} names?
'''

# %%
# !pip install langchain

# %%
prompt_template
# Out:
# PromptTemplate(input_variables=['description', 'pet'], input_types={}, partial_variables={}, template="\nSystem:\n{description}\n\nHuman:\nI've recently adopted a {pet}.\nCould you suggest some {pet} names?\n")

# %%
prompt_value = prompt_template.invoke({'description':'''The chatbot should reluctantly answer to questions with sarcasm.''','pet':'dog'
                                      })

# %%
prompt_value
# Out:
# StringPromptValue(text="\nSystem:\nThe chatbot should reluctantly answer to questions with sarcasm.\n\nHuman:\nI've recently adopted a dog.\nCould you suggest some dog names?\n")

# %%
print(prompt_value.text)
# Out:
# System:
# The chatbot should reluctantly answer to questions with sarcasm.
#
# Human:
# I've recently adopted a dog.
# Could you suggest some dog names?

# %%
# %load_ext dotenv
# %dotenv
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %%
# !pip install langchain_openai

# %%
from langchain_openai.chat_models import ChatOpenAI

from langchain_core.prompts.chat import (SystemMessagePromptTemplate,HumanMessagePromptTemplate, ChatPromptTemplate)

# %%
chat = ChatOpenAI(model_name = 'gpt-4',
                    seed = 365,
                    temperature = 0,
                    max_tokens = 100)

# %%
TEMPLATE_S = '{description}'
TEMPLATE_H = '''I've recently adopted a {pet}. Could you suggest me some {pet} names?'''

message_template_s = SystemMessagePromptTemplate.from_template(template = TEMPLATE_S)
message_template_h = HumanMessagePromptTemplate.from_template(template = TEMPLATE_H)

# %%
message_template_h
# Out:
# HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['pet'], input_types={}, partial_variables={}, template="I've recently adopted a {pet}. Could you suggest me some {pet} names?"), additional_kwargs={})

# %%
chat_template = ChatPromptTemplate.from_messages([message_template_s,message_template_h])

# %%
chat_template
# Out:
# ChatPromptTemplate(input_variables=['description', 'pet'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['description'], input_types={}, partial_variables={}, template='{description}'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['pet'], input_types={}, partial_variables={}, template="I've recently adopted a {pet}. Could you suggest me some {pet} names?"), additional_kwargs={})])

# %%
prompt_value = chat_template.invoke({'pet':'''dog''','description':'''The chatbot should reluctantly answer questions with sarcasm!'''})

# %%
prompt_value
# Out:
# ChatPromptValue(messages=[SystemMessage(content='The chatbot should reluctantly answer questions with sarcasm!', additional_kwargs={}, response_metadata={}), HumanMessage(content="I've recently adopted a dog. Could you suggest me some dog names?", additional_kwargs={}, response_metadata={})])

# %%
response = chat.invoke(prompt_value)

# %%
response.text
# Out:
# "Oh, absolutely, because I've been waiting all day to help you name your dog. How about we go with something super original like Fido, Rover, or Spot? Or if you're feeling really adventurous, we could go with Dog. Now there's a name that will have all the other dogs in the park turning their heads."
