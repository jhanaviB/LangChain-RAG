# %%
# %load_ext dotenv
# %dotenv

# %%
from langchain_openai.embeddings import OpenAIEmbeddings
from langchain_chroma import Chroma
from langchain_core.documents import Document

# %%
embedding = OpenAIEmbeddings(model="text-embedding-ada-002")

# %%
vectorstore_from_directory = Chroma(persist_directory = "./intro-to-ds-lectures",
                                    embedding_function = embedding)

# %%
vectorstore_from_directory.get(ids = "f52c63f2-ab89-4355-b6c6-f3408a72996b",include = ["embeddings"])
# Out:
# {'ids': ['f52c63f2-ab89-4355-b6c6-f3408a72996b'],
#  'embeddings': array([[ 0.00571892, -0.02316084,  0.03221191, ...,  0.01521325,
#          -0.00926805, -0.00610018]], shape=(1, 1536)),
#  'documents': None,
#  'uris': None,
#  'included': ['embeddings'],
#  'data': None,
#  'metadatas': None}
